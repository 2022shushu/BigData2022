# %%
import os
import warnings
warnings.simplefilter(action='ignore', category = FutureWarning)

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from scipy import stats
import pandas as pd
import numpy as np
from matplotlib import rc

import os
if os.name == 'nt' :
    font_family = "Malgun Gothic"
else :
    font_family = "AppleGothic"

sns.set(font = font_family, rc = {"axes.unicode_minus" : False})


df = pd.read_csv('C:/Users/user/Desktop/서빅캠 공모전/행정동.csv', encoding='cp949')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426 entries, 0 to 425
# Data columns (total 8 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   시군구                           426 non-null    object
#  1   행정동                           426 non-null    object
#  2   기초생활수급자인구밀도 (인원 수 / 면적 (k㎡))  426 non-null    float64
#  3   미세먼지                          426 non-null    int64
#  4   저소득층_비율                       426 non-null    float64
#  5   초미세먼지                         426 non-null    int64
#  6   행정동별_평균생활인구수 (야간)             426 non-null    float64
#  7   행정동별_평균생활인구수 (주간)             426 non-null    float64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 26.8+ KB

# %%
df.corr()
# Out:
#                               기초생활수급자인구밀도 (인원 수 / 면적 (k㎡))      미세먼지  \
# 기초생활수급자인구밀도 (인원 수 / 면적 (k㎡))                      1.000000  0.027611
# 미세먼지                                              0.027611  1.000000
# 저소득층_비율                                           0.205247 -0.125368
# 초미세먼지                                             0.056802  0.475173
# 행정동별_평균생활인구수 (야간)                                -0.013673 -0.086958
# 행정동별_평균생활인구수 (주간)                                -0.181287 -0.029992
#
#                                저소득층_비율     초미세먼지  행정동별_평균생활인구수 (야간)  \
# 기초생활수급자인구밀도 (인원 수 / 면적 (k㎡))  0.205247  0.056802          -0.013673
# 미세먼지                         -0.125368  0.475173          -0.086958
# 저소득층_비율                       1.000000  0.028297           0.695538
# 초미세먼지                         0.028297  1.000000           0.038414
# 행정동별_평균생활인구수 (야간)             0.695538  0.038414           1.000000
# 행정동별_평균생활인구수 (주간)             0.405543  0.059963           0.831563
#
#                               행정동별_평균생활인구수 (주간)
# 기초생활수급자인구밀도 (인원 수 / 면적 (k㎡))          -0.181287
# 미세먼지                                  -0.029992
# 저소득층_비율                                0.405543
# 초미세먼지                                  0.059963
# 행정동별_평균생활인구수 (야간)                      0.831563
# 행정동별_평균생활인구수 (주간)                      1.000000

# %%
colormap = plt.cm.PuBu
plt.figure(figsize=(10, 8))
plt.title("행정동 데이터간 상관관계", y = 1.05, size = 15)
sns.heatmap(df.corr(),vmin=-1,vmax=1,annot=True,linewidths=0.2,cmap='Reds')
plt.show()
